# %%
# import zipfile

# def unzip_file(zip_filepath, extract_dir):
#   with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
#     zip_ref.extractall(extract_dir)

# zip_file_path = '/content/drive/MyDrive/Colab Notebooks/Vehicle_siren_sound/archive.zip'
# extract_directory = '/content/drive/MyDrive/Colab Notebooks/Vehicle_siren_sound/'

# unzip_file(zip_file_path, extract_directory)

# %%
# import zipfile

# def unzip_file(zip_filepath, extract_dir):
#   with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
#     zip_ref.extractall(extract_dir)

# zip_file_path = '/content/drive/MyDrive/Colab Notebooks/Vehicle_siren_sound/emergency-vehicle-sirens-with-traffic-noise.zip'
# extract_directory = '/content/drive/MyDrive/Colab Notebooks/Vehicle_siren_sound/'

# unzip_file(zip_file_path, extract_directory)

# %%
# ! pip install kaggle

# %%
# # prompt: move  zip file to drive

# import shutil
# shutil.move('/content/emergency-vehicle-sirens-with-traffic-noise.zip', '/content/drive/MyDrive/Colab Notebooks/Vehicle_siren_sound')

# %%
# # prompt: move all the file in folder to other folder

# import shutil
# import os

# source_folder = '/content/drive/MyDrive/Colab Notebooks/Vehicle_siren_sound/Dataset/Dataset/firetruck'
# destination_folder = '/content/drive/MyDrive/Colab Notebooks/Vehicle_siren_sound/sounds/firetruck'

# # Ensure the destination folder exists
# os.makedirs(destination_folder, exist_ok=True)

# for filename in os.listdir(source_folder):
#     source_path = os.path.join(source_folder, filename)
#     destination_path = os.path.join(destination_folder, filename)

#     try:
#         if os.path.isfile(source_path):
#             shutil.move(source_path, destination_path)
#             print(f"Moved '{filename}' to '{destination_folder}'")
#         else:
#             print(f"Skipping '{filename}' (not a file)")
#     except Exception as e:
#         print(f"Error moving '{filename}': {e}")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall librosa -y  # Uninstall the current version
# !pip install librosa==0.9.2 # Install version 0.9.2
# Out:
# Found existing installation: librosa 0.10.2.post1
# Uninstalling librosa-0.10.2.post1:
#   Successfully uninstalled librosa-0.10.2.post1
# Collecting librosa==0.9.2
#   Downloading librosa-0.9.2-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (3.0.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (1.4.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (4.4.2)
# Collecting resampy>=0.2.2 (from librosa==0.9.2)
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (0.60.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (0.13.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.9.2) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.45.1->librosa==0.9.2) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.0->librosa==0.9.2) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.0->librosa==0.9.2) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.19.1->librosa==0.9.2) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.10.2->librosa==0.9.2) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.2) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2025.1.31)
# Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 3.7 MB/s eta 0:00:00
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 47.2 MB/s eta 0:00:00
# Installing collected packages: resampy, librosa
# Successfully installed librosa-0.9.2 resampy-0.4.3

# %%
#importing libraries
import os
import pickle
import librosa
import numpy as np
import librosa.display
import pandas as pd
import seaborn as sns
from scipy import signal
import IPython.display as ipd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
# base_directory="/content/drive/MyDrive/sounds"
base_directory="/content/drive/MyDrive/sounds"

# %%
def display_audio_waveform(folder,file_name):
  file_path=os.path.join(base_directory,folder,file_name)
  try:
    data, sample_rate = librosa.load(file_path)
    plt.figure(figsize=(14, 5))
    librosa.display.waveshow(data, sr=sample_rate)
    plt.show()
    ipd.display(ipd.Audio(file_path))

  except FileNotFoundError:
    print(f"Error: File not found at path: {file_path}")
  except Exception as e:
    print(f"An error occurred: {e}")

# %%
#evaluvate and explore dataset
folder = "ambulance"
file_name= "sound_1.wav"
display_audio_waveform(folder,file_name)
# Out:
# An error occurred: '_process_plot_var_args' object has no attribute 'prop_cycler'

# %%
#evaluvate and explore dataset
folder = "traffic"
file_name= "sound_401.wav"
display_audio_waveform(folder,file_name)
# Out:
# An error occurred: '_process_plot_var_args' object has no attribute 'prop_cycler'

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.18.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine_rl, tensorflow-text, tf_keras

# %%
#features_extractor to get a 80 MFCCs from each audio

def features_extractor(file_name):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=80)
    mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)

    return mfccs_scaled_features

# %%
audio_dataset_path = base_directory

extracted_features = []
for path in os.listdir(audio_dataset_path):
    for file in os.listdir(audio_dataset_path+"/"+path+"/"):
        if file.lower().endswith(".wav"):
            file_name = audio_dataset_path+"/"+path+"/"+file
            data = features_extractor(file_name)
            extracted_features.append([data, path])

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
f = open('./Extracted_Features.pkl', 'wb')
pickle.dump(extracted_features, f)
f.close()

# %%
f = open('./Extracted_Features.pkl', 'rb')
Data = pickle.load(f)
f.close()

# %%
df = pd.DataFrame(Data,columns=['feature','class'])
df.head()
# Out:
#                                              feature      class
# 0  [-529.2778, 96.09123, -46.660313, -12.780941, ...  ambulance
# 1  [-118.98806, 113.261086, -38.593113, -1.789974...  ambulance
# 2  [-38.777115, 104.3772, -40.953793, 1.8485571, ...  ambulance
# 3  [-164.77432, 126.585754, -35.331738, -14.7402,...  ambulance
# 4  [-521.1548, 95.068886, -53.56713, -10.641551, ...  ambulance

# %%
df['class'].value_counts()
# Out:
# class
# ambulance    600
# firetruck    600
# police       454
# traffic      200
# Name: count, dtype: int64

# %%
X = np.array(df['feature'].tolist())
Y = np.array(df['class'].tolist())

# %%
X.shape
# Out:
# (1854, 80)

# %%
Y.shape
# Out:
# (1854,)

# %%
labelencoder = LabelEncoder()
y = to_categorical(labelencoder.fit_transform(Y))

# %%
with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(labelencoder, f)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y, shuffle=True)

# %%
y_train.shape
# Out:
# (1483, 4)

# %% [markdown]
# # Train the model

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.14.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
from keras.layers import *
from keras.models import *
from keras.callbacks import *
from keras import backend as K
from sklearn import metrics
from keras.callbacks import ModelCheckpoint, EarlyStopping
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV
from datetime import datetime

# %%
X_train_features  = X_train.reshape(len(X_train),-1,1)
X_test_features = X_test.reshape(len(X_test),-1,1)
print("Reshaped Array Size", X_train_features.shape)
# Out:
# Reshaped Array Size (1483, 80, 1)

# %%
X_train.shape
# Out:
# (1483, 80)

# %%
def cnn(optimizer="adam", activation="relu", dropout_rate=0.5):
    K.clear_session()
    inputs = Input(shape=(X_train_features.shape[1], X_train_features.shape[2]))

    #First Conv1D layer
    conv = Conv1D(3, 13, padding='same', activation=activation)(inputs)
    if dropout_rate != 0:
        conv = Dropout(dropout_rate)(conv)
    conv = MaxPooling1D(2)(conv)

    #Second Conv1D layer
    conv = Conv1D(16, 11, padding='same', activation=activation)(conv)
    if dropout_rate != 0:
        conv = Dropout(dropout_rate)(conv)
    conv = MaxPooling1D(2)(conv)

    #MaxPooling 1D
    conv = GlobalMaxPool1D()(conv)

    #Dense Layer
    conv = Dense(16, activation=activation)(conv)
    outputs = Dense(y_test.shape[1], activation='softmax')(conv)

    model = Model(inputs, outputs)
    model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['acc'])
    return model

# %%
model_cnn = cnn(optimizer="adam", activation="relu", dropout_rate=0)
model_cnn.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 80, 1)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 80, 3)               │              42 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 40, 3)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 40, 16)              │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 20, 16)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d                 │ (None, 16)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │              68 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 926 (3.62 KB)
#  Trainable params: 926 (3.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_cnn, show_shapes=True, show_layer_names=True)

# %%
early_stop = EarlyStopping(monitor = 'val_accuracy', mode ='max',
                          patience = 10, restore_best_weights = True)

history = model_cnn.fit(X_train_features, y_train, epochs = 100,
                       callbacks = [early_stop],
                       batch_size = 64, validation_data = (X_test_features, y_test))
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - acc: 0.1300 - loss: 3.9041 - val_acc: 0.3019 - val_loss: 1.0609
# Epoch 2/100
#  1/24 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - acc: 0.3750 - loss: 0.9652
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: acc,loss,val_acc,val_loss
#   current = self.get_monitor_value(logs)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - acc: 0.3357 - loss: 0.7941 - val_acc: 0.4825 - val_loss: 0.5494
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - acc: 0.5066 - loss: 0.5069 - val_acc: 0.5310 - val_loss: 0.4585
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - acc: 0.5239 - loss: 0.4385 - val_acc: 0.5418 - val_loss: 0.4293
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.5780 - loss: 0.4140 - val_acc: 0.5768 - val_loss: 0.4074
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - acc: 0.6110 - loss: 0.3941 - val_acc: 0.6173 - val_loss: 0.3915
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - acc: 0.6288 - loss: 0.3841 - val_acc: 0.6334 - val_loss: 0.3809
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - acc: 0.6691 - loss: 0.3729 - val_acc: 0.6873 - val_loss: 0.3667
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - acc: 0.6925 - loss: 0.3627 - val_acc: 0.6873 - val_loss: 0.3575
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - acc: 0.7011 - loss: 0.3564 - val_acc: 0.6523 - val_loss: 0.3560
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.6935 - loss: 0.3429 - val_acc: 0.7116 - val_loss: 0.3422
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - acc: 0.7004 - loss: 0.3394 - val_acc: 0.7035 - val_loss: 0.3344
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - acc: 0.7102 - loss: 0.3254 - val_acc: 0.7089 - val_loss: 0.3291
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - acc: 0.7148 - loss: 0.3248 - val_acc: 0.7143 - val_loss: 0.3223
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - acc: 0.7306 - loss: 0.3139 - val_acc: 0.7251 - val_loss: 0.3176
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - acc: 0.7456 - loss: 0.3093 - val_acc: 0.7224 - val_loss: 0.3109
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - acc: 0.7350 - loss: 0.3036 - val_acc: 0.7278 - val_loss: 0.3061
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - acc: 0.7339 - loss: 0.2981 - val_acc: 0.7278 - val_loss: 0.3020
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - acc: 0.7519 - loss: 0.2945 - val_acc: 0.7278 - val_loss: 0.2993
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - acc: 0.7409 - loss: 0.2957 - val_acc: 0.7439 - val_loss: 0.2931
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.7577 - loss: 0.2891 - val_acc: 0.7520 - val_loss: 0.2890
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - acc: 0.7503 - loss: 0.2771 - val_acc: 0.7601 - val_loss: 0.2844
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.7603 - loss: 0.2762 - val_acc: 0.7736 - val_loss: 0.2790
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - acc: 0.7595 - loss: 0.2698 - val_acc: 0.7574 - val_loss: 0.2821
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - acc: 0.7569 - loss: 0.2720 - val_acc: 0.7628 - val_loss: 0.2725
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - acc: 0.7778 - loss: 0.2653 - val_acc: 0.7790 - val_loss: 0.2695
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - acc: 0.7632 - loss: 0.2610 - val_acc: 0.7763 - val_loss: 0.2643
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - acc: 0.7792 - loss: 0.2580 - val_acc: 0.7763 - val_loss: 0.2731
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - acc: 0.7746 - loss: 0.2599 - val_acc: 0.7682 - val_loss: 0.2627
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - acc: 0.7793 - loss: 0.2551 - val_acc: 0.7898 - val_loss: 0.2571
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - acc: 0.8071 - loss: 0.2113 - val_acc: 0.8032 - val_loss: 0.2276
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - acc: 0.8368 - loss: 0.1946 - val_acc: 0.8113 - val_loss: 0.2207
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8354 - loss: 0.2015 - val_acc: 0.8032 - val_loss: 0.2199
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - acc: 0.8241 - loss: 0.1965 - val_acc: 0.8086 - val_loss: 0.2218
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - acc: 0.8275 - loss: 0.2042 - val_acc: 0.7871 - val_loss: 0.2267
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8138 - loss: 0.2034 - val_acc: 0.8005 - val_loss: 0.2236
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8238 - loss: 0.2034 - val_acc: 0.8032 - val_loss: 0.2231
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8324 - loss: 0.1969 - val_acc: 0.8140 - val_loss: 0.2210
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - acc: 0.8212 - loss: 0.2031 - val_acc: 0.7898 - val_loss: 0.2266
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8274 - loss: 0.1881 - val_acc: 0.8086 - val_loss: 0.2366
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8369 - loss: 0.1892 - val_acc: 0.8059 - val_loss: 0.2281
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8331 - loss: 0.1932 - val_acc: 0.8032 - val_loss: 0.2214
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8419 - loss: 0.1882 - val_acc: 0.8005 - val_loss: 0.2229
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8187 - loss: 0.2063 - val_acc: 0.8059 - val_loss: 0.2237
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8252 - loss: 0.2039 - val_acc: 0.7978 - val_loss: 0.2251
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8386 - loss: 0.1903 - val_acc: 0.8005 - val_loss: 0.2208
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.8421 - loss: 0.1869 - val_acc: 0.8032 - val_loss: 0.2259
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8318 - loss: 0.1891 - val_acc: 0.8059 - val_loss: 0.2192
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8259 - loss: 0.1992 - val_acc: 0.8086 - val_loss: 0.2234
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8482 - loss: 0.1854 - val_acc: 0.8059 - val_loss: 0.2248
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8418 - loss: 0.1837 - val_acc: 0.8113 - val_loss: 0.2223
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8533 - loss: 0.1811 - val_acc: 0.8086 - val_loss: 0.2222
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8416 - loss: 0.1944 - val_acc: 0.8113 - val_loss: 0.2201
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8223 - loss: 0.2016 - val_acc: 0.8059 - val_loss: 0.2180
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8455 - loss: 0.1890 - val_acc: 0.8059 - val_loss: 0.2188
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8437 - loss: 0.1831 - val_acc: 0.8113 - val_loss: 0.2237
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8443 - loss: 0.1895 - val_acc: 0.8059 - val_loss: 0.2193
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8302 - loss: 0.1870 - val_acc: 0.8140 - val_loss: 0.2242
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8429 - loss: 0.1881 - val_acc: 0.8086 - val_loss: 0.2183

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Time')
plt.ylabel('Epoch')
plt.legend(['train', 'validation'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.xlabel('Time')
plt.ylabel('Epoch')
plt.legend(['train', 'validation'], loc = 'upper left')
plt.show()

# %%
_, acc = model_cnn.evaluate(X_test_features, y_test)
print("Test Accuracy : ", acc)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7883 - loss: 0.2246
# Test Accuracy :  0.808625340461731

# %%
y_pred = model_cnn.predict(X_test_features)

conf_mat = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
fig, ax = plt.subplots(figsize=(12,10))
sns.heatmap(conf_mat, annot=True, fmt='d', xticklabels=labelencoder.classes_, yticklabels=labelencoder.classes_, cbar=False)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
model_cnn.save('cnn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
with open('label_encoder.pkl', 'rb') as f:
    loaded_label_encoder = pickle.load(f)

# Verify it works
print("Loaded classes:", loaded_label_encoder.classes_)
# Out:
# Loaded classes: ['ambulance' 'firetruck' 'police' 'traffic']

# %%
# if you want model as function you can use this cell
from flask import Flask, request, jsonify
import numpy as np
import librosa
import pickle
from keras.models import load_model
from sklearn.preprocessing import LabelEncoder


model = load_model('/content/cnn_model.h5')

with open('/content/label_encoder.pkl', 'rb') as f:
   label_encoder = pickle.load(f)

def features_extractor(file_path):
    audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=80)
    mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
    return mfccs_scaled_features

# file = request.files['file']

# if not file.filename.endswith('.wav'):
#     # return jsonify({'error': 'Unsupported file format. Please upload a .wav file'}), 400
#     print("Unsupported file format. Please upload a .wav file")

try:
    # Save the uploaded file
    file_path ="/content/drive/MyDrive/Colab Notebooks/Vehicle_siren_sound/sounds/traffic/sound_405.wav"

    # file.save(file_path)

    features = features_extractor(file_path)
    features = features.reshape(1, -1, 1)

    # Make prediction
    predictions = model.predict(features)
    predicted_class = np.argmax(predictions, axis=1)
    class_label = label_encoder.inverse_transform(predicted_class)
    print(class_label)
    # return jsonify({'predicted_class': class_label[0]}), 200
    # print("predicted_class:", class_label[0])

except Exception as e:
  print(e)
    # return jsonify({'error': str(e)}), 500
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/Vehicle_siren_sound/sounds/traffic/sound_405.wav'
# /usr/local/lib/python3.11/dist-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)

# %% [markdown]
# # LSTM model

# %%
x_train_features  = X_train.reshape(len(X_train),-1, 80)
x_test_features = X_test.reshape(len(X_test), -1, 80)
print("Reshaped Array Size", x_train_features.shape)
# Out:
# Reshaped Array Size (1483, 1, 80)

# %%
def lstm(x_tr):
    K.clear_session()
    inputs = Input(shape=(x_tr.shape[1], x_tr.shape[2]))
    #lstm
    x = LSTM(128)(inputs)
    x = Dropout(0.5)(x)
    #dense
    x = Dense(64, activation='relu')(x)
    x = Dense(y_test.shape[1], activation='softmax')(x)
    model = Model(inputs, x)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
    return model

# %%
model_lstm = lstm(x_train_features)
model_lstm.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 1, 80)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 128)                 │         107,008 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 115,524 (451.27 KB)
#  Trainable params: 115,524 (451.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model_lstm, show_shapes=True, show_layer_names=True)

# %%
mc = ModelCheckpoint('best_model.keras', monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model_lstm.fit(x_train_features, y_train, epochs = 1000,
                        callbacks = [mc],
                        batch_size = 64, validation_data = (x_test_features, y_test))
# Out:
# Epoch 1/1000
# 20/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.2510 - loss: 0.6904
# Epoch 1: val_acc improved from -inf to 0.53100, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - acc: 0.2642 - loss: 0.6723 - val_acc: 0.5310 - val_loss: 0.4593
# Epoch 2/1000
# 16/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.5183 - loss: 0.4554
# Epoch 2: val_acc improved from 0.53100 to 0.65768, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.5239 - loss: 0.4520 - val_acc: 0.6577 - val_loss: 0.3952
# Epoch 3/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.5717 - loss: 0.4151
# Epoch 3: val_acc did not improve from 0.65768
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - acc: 0.5795 - loss: 0.4100 - val_acc: 0.6577 - val_loss: 0.3544
# Epoch 4/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.6216 - loss: 0.3760
# Epoch 4: val_acc improved from 0.65768 to 0.69811, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.6258 - loss: 0.3720 - val_acc: 0.6981 - val_loss: 0.3256
# Epoch 5/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.6701 - loss: 0.3428
# Epoch 5: val_acc improved from 0.69811 to 0.78167, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.6747 - loss: 0.3396 - val_acc: 0.7817 - val_loss: 0.2954
# Epoch 6/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.6821 - loss: 0.3140
# Epoch 6: val_acc did not improve from 0.78167
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.6900 - loss: 0.3115 - val_acc: 0.7601 - val_loss: 0.2790
# Epoch 7/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.7431 - loss: 0.2828
# Epoch 7: val_acc improved from 0.78167 to 0.78706, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.7432 - loss: 0.2827 - val_acc: 0.7871 - val_loss: 0.2573
# Epoch 8/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.7507 - loss: 0.2658
# Epoch 8: val_acc improved from 0.78706 to 0.80054, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.7529 - loss: 0.2662 - val_acc: 0.8005 - val_loss: 0.2407
# Epoch 9/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.7676 - loss: 0.2558
# Epoch 9: val_acc did not improve from 0.80054
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.7691 - loss: 0.2534 - val_acc: 0.8005 - val_loss: 0.2324
# Epoch 10/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.7890 - loss: 0.2430
# Epoch 10: val_acc improved from 0.80054 to 0.80863, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.7889 - loss: 0.2423 - val_acc: 0.8086 - val_loss: 0.2230
# Epoch 11/1000
# 20/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.7959 - loss: 0.2339
# Epoch 11: val_acc did not improve from 0.80863
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.7955 - loss: 0.2336 - val_acc: 0.8059 - val_loss: 0.2181
# Epoch 12/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8155 - loss: 0.2213
# Epoch 12: val_acc improved from 0.80863 to 0.82749, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8150 - loss: 0.2215 - val_acc: 0.8275 - val_loss: 0.2098
# Epoch 13/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8266 - loss: 0.1984
# Epoch 13: val_acc did not improve from 0.82749
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.8231 - loss: 0.2025 - val_acc: 0.8167 - val_loss: 0.2103
# Epoch 14/1000
# 16/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.8189 - loss: 0.2050
# Epoch 14: val_acc did not improve from 0.82749
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8169 - loss: 0.2063 - val_acc: 0.8194 - val_loss: 0.2028
# Epoch 15/1000
# 16/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.8194 - loss: 0.2036
# Epoch 15: val_acc did not improve from 0.82749
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8215 - loss: 0.2007 - val_acc: 0.8194 - val_loss: 0.2040
# Epoch 16/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8471 - loss: 0.1909
# Epoch 16: val_acc did not improve from 0.82749
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.8444 - loss: 0.1930 - val_acc: 0.8221 - val_loss: 0.2047
# Epoch 17/1000
# 21/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.8466 - loss: 0.1890
# Epoch 17: val_acc improved from 0.82749 to 0.83019, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.8445 - loss: 0.1899 - val_acc: 0.8302 - val_loss: 0.2055
# Epoch 18/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8240 - loss: 0.1995
# Epoch 18: val_acc did not improve from 0.83019
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.8266 - loss: 0.1971 - val_acc: 0.8059 - val_loss: 0.2059
# Epoch 19/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8132 - loss: 0.1932
# Epoch 19: val_acc did not improve from 0.83019
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.8184 - loss: 0.1906 - val_acc: 0.8221 - val_loss: 0.1926
# Epoch 20/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8370 - loss: 0.1782
# Epoch 20: val_acc improved from 0.83019 to 0.83827, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8361 - loss: 0.1785 - val_acc: 0.8383 - val_loss: 0.1924
# Epoch 21/1000
# 16/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.8432 - loss: 0.1823
# Epoch 21: val_acc did not improve from 0.83827
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8424 - loss: 0.1832 - val_acc: 0.8329 - val_loss: 0.1962
# Epoch 22/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8459 - loss: 0.1726
# Epoch 22: val_acc did not improve from 0.83827
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.8476 - loss: 0.1728 - val_acc: 0.8275 - val_loss: 0.1904
# Epoch 23/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8560 - loss: 0.1723
# Epoch 23: val_acc did not improve from 0.83827
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8557 - loss: 0.1719 - val_acc: 0.8032 - val_loss: 0.2107
# Epoch 24/1000
# 17/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8539 - loss: 0.1630
# Epoch 24: val_acc did not improve from 0.83827
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8513 - loss: 0.1641 - val_acc: 0.8329 - val_loss: 0.1887
# Epoch 25/1000
# 16/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.8587 - loss: 0.1607
# Epoch 25: val_acc did not improve from 0.83827
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8567 - loss: 0.1617 - val_acc: 0.8302 - val_loss: 0.1967
# Epoch 26/1000
# 17/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.8425 - loss: 0.1696
# Epoch 26: val_acc did not improve from 0.83827
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8449 - loss: 0.1683 - val_acc: 0.8248 - val_loss: 0.1938
# Epoch 27/1000
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.
val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - acc: 0.9030 - loss: 0.1106 - val_acc: 0.8571 - val_loss: 0.1839
# Epoch 72/1000
# 22/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9054 - loss: 0.1076
# Epoch 72: val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9051 - loss: 0.1079 - val_acc: 0.8491 - val_loss: 0.1889
# Epoch 73/1000
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9067 - loss: 0.1008
# Epoch 73: val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9072 - loss: 0.1008 - val_acc: 0.8544 - val_loss: 0.1877
# Epoch 74/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9202 - loss: 0.0976
# Epoch 74: val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - acc: 0.9203 - loss: 0.0975 - val_acc: 0.8491 - val_loss: 0.2189
# Epoch 75/1000
# 22/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9219 - loss: 0.1039
# Epoch 75: val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9216 - loss: 0.1031 - val_acc: 0.8491 - val_loss: 0.1920
# Epoch 76/1000
# 20/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9201 - loss: 0.0914
# Epoch 76: val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - acc: 0.9180 - loss: 0.0927 - val_acc: 0.8491 - val_loss: 0.1917
# Epoch 77/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8959 - loss: 0.1103
# Epoch 77: val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.8962 - loss: 0.1100 - val_acc: 0.8383 - val_loss: 0.1861
# Epoch 78/1000
# 17/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.9359 - loss: 0.0848
# Epoch 78: val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - acc: 0.9317 - loss: 0.0883 - val_acc: 0.8464 - val_loss: 0.1953
# Epoch 79/1000
# 17/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.9263 - loss: 0.0971
# Epoch 79: val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9239 - loss: 0.0975 - val_acc: 0.8544 - val_loss: 0.1923
# Epoch 80/1000
# 17/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.9065 - loss: 0.1105
# Epoch 80: val_acc did not improve from 0.85714
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9054 - loss: 0.1108 - val_acc: 0.8383 - val_loss: 0.1941
# Epoch 81/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.8969 - loss: 0.1036
# Epoch 81: val_acc improved from 0.85714 to 0.85984, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8986 - loss: 0.1041 - val_acc: 0.8598 - val_loss: 0.1822
# Epoch 82/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.9010 - loss: 0.1071
# Epoch 82: val_acc did not improve from 0.85984
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9050 - loss: 0.1052 - val_acc: 0.8571 - val_loss: 0.1878
# Epoch 83/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.9166 - loss: 0.0902
# Epoch 83: val_acc did not improve from 0.85984
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9198 - loss: 0.0890 - val_acc: 0.8544 - val_loss: 0.2043
# Epoch 84/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.9244 - loss: 0.0867
# Epoch 84: val_acc did not improve from 0.85984
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9232 - loss: 0.0893 - val_acc: 0.8464 - val_loss: 0.1842
# Epoch 85/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.9133 - loss: 0.0996
# Epoch 85: val_acc did not improve from 0.85984
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.9134 - loss: 0.0994 - val_acc: 0.8491 - val_loss: 0.2094
# Epoch 86/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.9458 - loss: 0.0787
# Epoch 86: val_acc improved from 0.85984 to 0.86253, saving model to best_model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.9415 - loss: 0.0818 - val_acc: 0.8625 - val_loss: 0.1831
# Epoch 87/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.9367 - loss: 0.0816
# Epoch 87: val_acc did not improve from 0.86253
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9344 - loss: 0.0834 - val_acc: 0.8571 - val_loss: 0.2006
# Epoch 88/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.9087 - loss: 0.1006
# Epoch 88: val_acc did not improve from 0.86253
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9111 - loss: 0.0981 - val_acc: 0.8518 - val_loss: 0.1927
# Epoch 89/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.9323 - loss: 0.0882
# Epoch 89: val_acc did not improve from 0.86253
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9329 - loss: 0.0879 - val_acc: 0.8491 - val_loss: 0.1954
# Epoch 90/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.9227 - loss: 0.0867
# Epoch 90: val_acc did not improve from 0.86253
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9210 - loss: 0.0879 - val_acc: 0.8598 - val_loss: 0.1914
# Epoch 91/1000
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.9297 - loss: 0.0869
# Epoch 91: val_acc did not improve from 0.86253
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.9294 - loss: 0.0872 - val_acc: 0.8571 - val_loss: 0.1882
# Epoch 92/1000
# 21/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.
1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9823 - loss: 0.0264
# Epoch 983: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.9828 - loss: 0.0251 - val_acc: 0.8679 - val_loss: 0.4215
# Epoch 984/1000
# 21/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9780 - loss: 0.0252
# Epoch 984: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - acc: 0.9780 - loss: 0.0250 - val_acc: 0.8598 - val_loss: 0.4442
# Epoch 985/1000
# 20/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9816 - loss: 0.0207
# Epoch 985: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.9814 - loss: 0.0206 - val_acc: 0.8544 - val_loss: 0.4367
# Epoch 986/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.9810 - loss: 0.0247
# Epoch 986: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - acc: 0.9811 - loss: 0.0246 - val_acc: 0.8706 - val_loss: 0.4075
# Epoch 987/1000
# 21/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9823 - loss: 0.0267
# Epoch 987: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - acc: 0.9826 - loss: 0.0255 - val_acc: 0.8679 - val_loss: 0.4268
# Epoch 988/1000
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.9860 - loss: 0.0173
# Epoch 988: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - acc: 0.9861 - loss: 0.0174 - val_acc: 0.8733 - val_loss: 0.4596
# Epoch 989/1000
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.9888 - loss: 0.0140
# Epoch 989: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.9888 - loss: 0.0140 - val_acc: 0.8598 - val_loss: 0.4559
# Epoch 990/1000
# 20/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.9884 - loss: 0.0203
# Epoch 990: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - acc: 0.9886 - loss: 0.0197 - val_acc: 0.8733 - val_loss: 0.4269
# Epoch 991/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9881 - loss: 0.0142
# Epoch 991: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - acc: 0.9882 - loss: 0.0143 - val_acc: 0.8625 - val_loss: 0.4381
# Epoch 992/1000
# 21/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.9864 - loss: 0.0145
# Epoch 992: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - acc: 0.9870 - loss: 0.0143 - val_acc: 0.8652 - val_loss: 0.4374
# Epoch 993/1000
# 22/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9864 - loss: 0.0206
# Epoch 993: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - acc: 0.9862 - loss: 0.0206 - val_acc: 0.8652 - val_loss: 0.4341
# Epoch 994/1000
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9832 - loss: 0.0262
# Epoch 994: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9828 - loss: 0.0264 - val_acc: 0.8625 - val_loss: 0.4402
# Epoch 995/1000
# 22/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9750 - loss: 0.0284
# Epoch 995: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - acc: 0.9759 - loss: 0.0279 - val_acc: 0.8598 - val_loss: 0.4237
# Epoch 996/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9809 - loss: 0.0240
# Epoch 996: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - acc: 0.9809 - loss: 0.0240 - val_acc: 0.8652 - val_loss: 0.4249
# Epoch 997/1000
# 18/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9841 - loss: 0.0273
# Epoch 997: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.9840 - loss: 0.0260 - val_acc: 0.8706 - val_loss: 0.4445
# Epoch 998/1000
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9925 - loss: 0.0129
# Epoch 998: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9921 - loss: 0.0132 - val_acc: 0.8679 - val_loss: 0.4918
# Epoch 999/1000
# 21/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9895 - loss: 0.0169
# Epoch 999: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9889 - loss: 0.0171 - val_acc: 0.8491 - val_loss: 0.4407
# Epoch 1000/1000
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.9804 - loss: 0.0228
# Epoch 1000: val_acc did not improve from 0.87871
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9808 - loss: 0.0224 - val_acc: 0.8598 - val_loss: 0.4596

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Time')
plt.ylabel('epoch')
plt.legend(['train','validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.xlabel('Time')
plt.ylabel('Epoch')
plt.legend(['train', 'validation'], loc = 'upper left')
plt.show()

# %%
_,acc = model_lstm.evaluate(x_test_features, y_test)
print("Accuracy:", acc)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.8500 - loss: 0.5523
# Accuracy: 0.8598382472991943

# %%
y_pred = model_lstm.predict(x_test_features)

conf_mat = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
fig, ax = plt.subplots(figsize=(12,10))
sns.heatmap(conf_mat, annot=True, fmt='d', xticklabels=labelencoder.classes_, yticklabels=labelencoder.classes_, cbar=False)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
model_lstm.save('lstm_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
